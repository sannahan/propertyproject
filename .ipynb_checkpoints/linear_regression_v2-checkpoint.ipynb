# %% [markdown]
# # Linear regression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

csv_file = 'preprocessed_data/preprocessed_merged_apartments_population_2011-2022.csv'

apartments_df = pd.read_csv(csv_file)

apartments_df.head()
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#    Year              City  Rooms  Rent per m2  Rental apartment count  \
# 0  2011          Helsinki      1        18.83                    9050
# 1  2011          Helsinki      2        14.20                    5949
# 2  2011          Helsinki      3        12.22                    2181
# 3  2011  Espoo-Kauniainen      1        15.72                    1217
# 4  2011  Espoo-Kauniainen      2        13.88                    1318
#
#    Sales price per m2  Sold apartments count  \
# 0                4645                   3154
# 1                3966                   4973
# 2                3987                   3476
# 3                3525                    370
# 4                3209                   1085
#
#    Rent €/mo vs. sales price k€ per m2  Total population
# 0                             4.053821          591966.5
# 1                             3.580434          591966.5
# 2                             3.064961          591966.5
# 3                             4.459574          258952.5
# 4                             4.325335          258952.5

# %% [markdown]
# ##### Sales price vs. population

# %%
cities = apartments_df['City'].unique()

for city in cities:
    city_data = apartments_df[apartments_df['City'] == city]
    one_room = city_data[city_data["Rooms"]==1]
    two_room = city_data[city_data["Rooms"]==2]
    three_room = city_data[city_data["Rooms"]==3]
    
    print(f"City: {city}")

    X = one_room['Total population'].values.reshape(-1, 1)
    y = one_room['Sales price per m2'].values
    
    model = LinearRegression().fit(X, y)
    slope = model.coef_
    
    print(f"Slope one room (Population Coefficient): {slope}")

    X = two_room['Total population'].values.reshape(-1, 1)
    y = two_room['Sales price per m2'].values
    
    model = LinearRegression().fit(X, y)
    slope = model.coef_[0]
    
    print(f"Slope two room (Population Coefficient): {slope:.2f}")

    X = three_room['Total population'].values.reshape(-1, 1)
    y = three_room['Sales price per m2'].values
    
    model = LinearRegression().fit(X, y)
    slope = model.coef_[0]
    
    print(f"Slope three room (Population Coefficient): {slope:.2f}")

    sns.regplot(x="Total population", y="Sales price per m2", data=city_data[city_data["Rooms"]==1], ci=None, label="One room")
    sns.regplot(x="Total population", y="Sales price per m2", data=city_data[city_data["Rooms"]==2], ci=None, label="Two room")
    sns.regplot(x="Total population", y="Sales price per m2", data=city_data[city_data["Rooms"]==3], ci=None, label="Three room")
    plt.legend()
    plt.show()
# Out:
# City: Helsinki
# Slope one room (Population Coefficient): [0.03397254]
# Slope two room (Population Coefficient): 0.03
# Slope three room (Population Coefficient): 0.02
# City: Espoo-Kauniainen
# Slope one room (Population Coefficient): [0.02266826]
# Slope two room (Population Coefficient): 0.02
# Slope three room (Population Coefficient): 0.02
# City: Vantaa
# Slope one room (Population Coefficient): [0.01824344]
# Slope two room (Population Coefficient): 0.01
# Slope three room (Population Coefficient): 0.00
# City: Porvoo
# Slope one room (Population Coefficient): [0.16868267]
# Slope two room (Population Coefficient): 0.13
# Slope three room (Population Coefficient): 0.21
# City: Tampere
# Slope one room (Population Coefficient): [0.0399038]
# Slope two room (Population Coefficient): 0.03
# Slope three room (Population Coefficient): 0.03
# City: Turku
# Slope one room (Population Coefficient): [0.08306084]
# Slope two room (Population Coefficient): 0.05
# Slope three room (Population Coefficient): 0.04
# City: Pori
# Slope one room (Population Coefficient): [-0.02037059]
# Slope two room (Population Coefficient): 0.05
# Slope three room (Population Coefficient): 0.01
# City: Lappeenranta
# Slope one room (Population Coefficient): [0.14114108]
# Slope two room (Population Coefficient): 0.04
# Slope three room (Population Coefficient): 0.00
# City: Kotka
# Slope one room (Population Coefficient): [0.01398004]
# Slope two room (Population Coefficient): 0.02
# Slope three room (Population Coefficient): 0.04
# City: Kouvola
# Slope one room (Population Coefficient): [0.02147275]
# Slope two room (Population Coefficient): 0.01
# Slope three room (Population Coefficient): 0.02
# City: Lahti
# Slope one room (Population Coefficient): [0.05228403]
# Slope two room (Population Coefficient): -0.01
# Slope three room (Population Coefficient): 0.01
# City: Hämeenlinna
# Slope one room (Population Coefficient): [0.10356829]
# Slope two room (Population Coefficient): 0.03
# Slope three room (Population Coefficient): 0.04
# City: Kuopio
# Slope one room (Population Coefficient): [0.03945071]
# Slope two room (Population Coefficient): 0.02
# Slope three room (Population Coefficient): 0.01
# City: Jyväskylä
# Slope one room (Population Coefficient): [0.03972581]
# Slope two room (Population Coefficient): 0.02
# Slope three room (Population Coefficient): 0.02
# City: Vaasa
# Slope one room (Population Coefficient): [0.11412571]
# Slope two room (Population Coefficient): 0.03
# Slope three room (Population Coefficient): 0.04
# City: Seinäjoki
# Slope one room (Population Coefficient): [0.08475899]
# Slope two room (Population Coefficient): 0.05
# Slope three room (Population Coefficient): 0.03
# City: Mikkeli
# Slope one room (Population Coefficient): [0.03551688]
# Slope two room (Population Coefficient): 0.10
# Slope three room (Population Coefficient): 0.07
# City: Joensuu
# Slope one room (Population Coefficient): [0.00865073]
# Slope two room (Population Coefficient): -0.02
# Slope three room (Population Coefficient): -0.02
# City: Oulu
# Slope one room (Population Coefficient): [0.04354068]
# Slope two room (Population Coefficient): 0.03
# Slope three room (Population Coefficient): 0.02
# City: Rovaniemi
# Slope one room (Population Coefficient): [0.09102384]
# Slope two room (Population Coefficient): 0.11
# Slope three room (Population Coefficient): 0.08

# %% [markdown]
# ##### Rent price vs. sales price

# %%
for city in cities:
    city_data = apartments_df[apartments_df['City'] == city]
    one_room = city_data[city_data["Rooms"]==1]
    two_room = city_data[city_data["Rooms"]==2]
    three_room = city_data[city_data["Rooms"]==3]
        
    X = city_data['Rent per m2'].values.reshape(-1, 1)
    y = city_data['Sales price per m2'].values
 
    print(f"City: {city}")

    X = one_room['Rent per m2'].values.reshape(-1, 1)
    y = one_room['Sales price per m2'].values
    
    model = LinearRegression().fit(X, y)
    slope = model.coef_[0]
    
    print(f"Slope one room: {slope:.2f}")

    X = two_room['Rent per m2'].values.reshape(-1, 1)
    y = two_room['Sales price per m2'].values
    
    model = LinearRegression().fit(X, y)
    slope = model.coef_[0]
    
    print(f"Slope two room: {slope:.2f}")

    X = three_room['Rent per m2'].values.reshape(-1, 1)
    y = three_room['Sales price per m2'].values
    
    model = LinearRegression().fit(X, y)
    slope = model.coef_[0]
    
    print(f"Slope three room: {slope:.2f}")

    sns.regplot(x="Rent per m2", y="Sales price per m2", data=city_data[city_data["Rooms"]==1], ci=None, label="One room")
    sns.regplot(x="Rent per m2", y="Sales price per m2", data=city_data[city_data["Rooms"]==2], ci=None, label="Two room")
    sns.regplot(x="Rent per m2", y="Sales price per m2", data=city_data[city_data["Rooms"]==3], ci=None, label="Three room")
    plt.legend()
    plt.show()
# Out:
# City: Helsinki
# Slope one room: 287.62
# Slope two room: 285.94
# Slope three room: 274.59
# City: Espoo-Kauniainen
# Slope one room: 135.50
# Slope two room: 216.02
# Slope three room: 185.50
# City: Vantaa
# Slope one room: 76.43
# Slope two room: 59.80
# Slope three room: 8.52
# City: Porvoo
# Slope one room: 66.95
# Slope two room: 83.92
# Slope three room: 115.47
# City: Tampere
# Slope one room: 234.11
# Slope two room: 249.75
# Slope three room: 239.77
# City: Turku
# Slope one room: 349.70
# Slope two room: 246.82
# Slope three room: 234.60
# City: Pori
# Slope one room: -4.97
# Slope two room: -50.70
# Slope three room: -6.40
# City: Lappeenranta
# Slope one room: 40.73
# Slope two room: 17.51
# Slope three room: -3.51
# City: Kotka
# Slope one room: -35.29
# Slope two room: -36.46
# Slope three room: -68.13
# City: Kouvola
# Slope one room: -69.26
# Slope two room: -84.31
# Slope three room: -43.79
# City: Lahti
# Slope one room: 41.24
# Slope two room: -21.01
# Slope three room: 9.08
# City: Hämeenlinna
# Slope one room: -26.19
# Slope two room: -39.88
# Slope three room: -23.39
# City: Kuopio
# Slope one room: 72.84
# Slope two room: 32.49
# Slope three room: 1.38
# City: Jyväskylä
# Slope one room: 116.23
# Slope two room: 81.15
# Slope three room: 115.01
# City: Vaasa
# Slope one room: 99.86
# Slope two room: 8.81
# Slope three room: 33.19
# City: Seinäjoki
# Slope one room: 162.54
# Slope two room: 116.58
# Slope three room: 67.29
# City: Mikkeli
# Slope one room: 10.26
# Slope two room: -84.38
# Slope three room: -58.20
# City: Joensuu
# Slope one room: 15.20
# Slope two room: -21.09
# Slope three room: -51.29
# City: Oulu
# Slope one room: 252.94
# Slope two room: 191.18
# Slope three room: 193.84
# City: Rovaniemi
# Slope one room: 89.24
# Slope two room: 128.41
# Slope three room: 94.98
