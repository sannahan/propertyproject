# %% [markdown]
# # Pairplots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

csv_file = 'preprocessed_data/preprocessed_merged_apartments_population_2011-2022.csv'

apartments_df = pd.read_csv(csv_file)

apartments_df.head()
# Out:
#    Year              City  Rooms  Rent per m2  Rental apartment count  \
# 0  2011          Helsinki      1        18.83                    9050
# 1  2011          Helsinki      2        14.20                    5949
# 2  2011          Helsinki      3        12.22                    2181
# 3  2011  Espoo-Kauniainen      1        15.72                    1217
# 4  2011  Espoo-Kauniainen      2        13.88                    1318
#
#    Sales price per m2  Sold apartments count  Total population
# 0                4645                   3154          591966.5
# 1                3966                   4973          591966.5
# 2                3987                   3476          591966.5
# 3                3525                    370          258952.5
# 4                3209                   1085          258952.5

# %%
cities = apartments_df['City'].unique()

for city in cities:
    city_data = apartments_df[apartments_df['City'] == city]
    
    print(f"City: {city}")
    
    sns.pairplot(city_data[['Year', 'Total population', 'Sales price per m2', 'Rent per m2']])
    plt.show()
# Out:
# City: Helsinki
# City: Espoo-Kauniainen
# City: Vantaa
# City: Porvoo
# City: Tampere
# City: Turku
# City: Pori
# City: Lappeenranta
# City: Kotka
# City: Kouvola
# City: Lahti
# City: Hämeenlinna
# City: Kuopio
# City: Jyväskylä
# City: Vaasa
# City: Seinäjoki
# City: Mikkeli
# City: Joensuu
# City: Oulu
# City: Rovaniemi
